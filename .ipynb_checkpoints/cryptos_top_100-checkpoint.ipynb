# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import time

def geckoList(page=1, per_page=250):
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {"vs_currency":"usd", "order":"market_cap_desc", "per_page":per_page, "page":page}
    r = requests.get(url, params).json()
    df = pd.DataFrame(r)
    df.set_index('symbol', inplace=True)
    return df

def geckoHistorical(ticker, vs_currency='usd', days='max'):
    url = f"https://api.coingecko.com/api/v3/coins/{ticker}/market_chart"
    params = {"vs_currency":{vs_currency}, "days":days}
    r = requests.get(url, params).json()
    prices = pd.DataFrame(r['prices'])
    market_caps = pd.DataFrame(r['market_caps'])
    total_volumes = pd.DataFrame(r['total_volumes'])
    df = pd.concat([prices, market_caps[1], total_volumes[1]], axis=1)
    df[0] = pd.to_datetime(df[0], unit='ms')
    df.columns = ['date','price','market_caps','total_volumes']
    df.set_index('date', inplace=True)
    return df

# %%
lista_ = geckoList(page=1, per_page=58)
lista = lista_['id'].tolist()

# %%
symbols = [x.upper() for x in lista_.index.values]

# %%
data = []
for coin in lista:
    try:
      data.append(geckoHistorical(coin, days=365)['price'].resample('1D').last())
    except:
      print(f'Fallo en {coin}')  
    time.sleep(1)

df = pd.DataFrame(data).T
df.columns = lista
df = df.loc[df.index >= '2021-11-10']
pd.options.display.max_columns=14
df
# Out:
#                  bitcoin     ethereum    tether  usd-coin  binancecoin  \
# date
# 2021-11-10  67145.374935  4742.080911  1.001149  1.001716   636.927618
# 2021-11-11  65061.054407  4641.528765  1.005009  1.003782   611.442281
# 2021-11-12  65005.645160  4732.924450  1.000689  1.001392   629.711420
# 2021-11-13  64432.047947  4685.106356  1.005498  1.005971   629.095105
# 2021-11-14  64660.335353  4666.498498  1.004166  1.003622   652.233782
# ...                  ...          ...       ...       ...          ...
# 2022-07-27  21235.612316  1438.988038  1.001113  1.000248   248.851235
# 2022-07-28  22908.884260  1636.949181  0.999395  1.000709   270.305244
# 2022-07-29  23822.067598  1723.548521  0.999281  1.002497   276.467954
# 2022-07-30  23847.583319  1739.042177  1.000496  0.999981   294.546622
# 2022-07-31  23821.140842  1696.615291  1.001191  1.001657   292.954093
#
#               ripple   cardano  ...  true-usd     helium        maker  \
# date                            ...
# 2021-11-10  1.261712  2.278047  ...  0.999907  47.409919  3138.951295
# 2021-11-11  1.188313  2.097095  ...  1.005846  49.533657  2959.298052
# 2021-11-12  1.217629  2.085169  ...  1.001506  48.749123  3003.659770
# 2021-11-13  1.194213  2.056788  ...  1.005568  51.416344  2883.349632
# 2021-11-14  1.193692  2.058331  ...  1.004157  51.016572  3151.181979
# ...              ...       ...  ...       ...        ...          ...
# 2022-07-27  0.336750  0.467789  ...  1.000959   8.627434   896.947008
# 2022-07-28  0.359549  0.509188  ...  0.999782   9.107500  1009.769206
# 2022-07-29  0.372412  0.513909  ...  0.999214   9.205957  1113.679589
# 2022-07-30  0.369844  0.525657  ...  0.997521   9.193901  1159.322874
# 2022-07-31  0.389375  0.529792  ...  0.999784   9.558341  1140.564275
#
#             compound-usd-coin  the-graph  kucoin-shares  klay-token
# date
# 2021-11-10           0.022394   1.209834      22.986936    1.599601
# 2021-11-11           0.022428   1.088059      22.387507    1.537683
# 2021-11-12           0.022396   1.114978      23.301104    1.557216
# 2021-11-13           0.022483   1.077460      22.450418    1.569030
# 2021-11-14           0.022412   1.101126      23.756389    1.550669
# ...                       ...        ...            ...         ...
# 2022-07-27           0.022607   0.097265       9.649177    0.246079
# 2022-07-28           0.022605   0.110937      10.207509    0.261178
# 2022-07-29           0.022644   0.115011      10.342114    0.276381
# 2022-07-30           0.022618   0.127642      10.241087    0.307518
# 2022-07-31           0.022649   0.136414      10.199048    0.313646
#
# [264 rows x 58 columns]

# %%
df.dtypes
# Out:
# bitcoin              float64
# ethereum             float64
# tether               float64
# usd-coin             float64
# binancecoin          float64
# ripple               float64
# cardano              float64
# binance-usd          float64
# solana               float64
# polkadot             float64
# dogecoin             float64
# matic-network        float64
# staked-ether         float64
# shiba-inu            float64
# dai                  float64
# avalanche-2          float64
# tron                 float64
# wrapped-bitcoin      float64
# ethereum-classic     float64
# okb                  float64
# leo-token            float64
# litecoin             float64
# ftx-token            float64
# uniswap              float64
# chainlink            float64
# crypto-com-chain     float64
# near                 float64
# cosmos               float64
# stellar              float64
# monero               float64
# bitcoin-cash         float64
# algorand             float64
# filecoin             float64
# internet-computer    float64
# flow                 float64
# apecoin              float64
# vechain              float64
# chain-2              float64
# decentraland         float64
# hedera-hashgraph     float64
# the-sandbox          float64
# axie-infinity        float64
# tezos                float64
# frax                 float64
# aave                 float64
# eos                  float64
# quant-network        float64
# theta-token          float64
# elrond-erd-2         float64
# lido-dao             float64
# bitcoin-cash-sv      float64
# true-usd             float64
# helium               float64
# maker                float64
# compound-usd-coin    float64
# the-graph            float64
# kucoin-shares        float64
# klay-token           float64
# dtype: object

# %%
df = df.fillna(method='ffill')
rendimientos_usd = df.iloc[-1] / df.iloc[0] - 1
rendimientos_btc = (df.iloc[-1] / df.iloc[0]) /  (df['bitcoin'].iloc[-1]/df['bitcoin'].iloc[0]) -1

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(24,10), nrows=2)


ax[0].set_title('\nTOP 50 mktCap - Rendimiento en BTC desde 10 Nov 2021 (ATH BTC)', fontsize=15)
colors = []
for i in range(50):
    value = rendimientos_btc.iloc[i]
    if value > 0 :
        colors.append('white')
    else:
        colors.append('tab:red')
    ax[0].annotate(f"{symbols[i]} {value:.0%}", xy = (df.columns[i], value*100+4), rotation=90, fontsize=11, color=colors[i])

ax[0].bar(rendimientos_btc.iloc[:-50].index, (rendimientos_btc*100).iloc[:-50], color=colors[:50], width=0.5, alpha=0.3)
ax[0].grid(alpha=0.3)
ax[0].set_xticklabels(symbols, rotation = 90, fontsize=11)
ax[0].set_ylim(-60,400)


ax[1].set_title('\nTOP 50/100 mktCap - Rendimiento en BTC desde 10 Nov 2021 (ATH BTC)', fontsize=15)
for i in range(50):
    value = rendimientos_btc.iloc[i]
    if value > 0 :
        colors.append('white')
    else:
        colors.append('tab:red')
    ax[1].annotate(f"{symbols[i]} {value:.0%}", xy = (df.columns[i], value*100+4), rotation=90, fontsize=11, color=colors[i])

ax[1].bar(rendimientos_btc.iloc[50:].index, (rendimientos_btc*100).iloc[50:], color=colors[50:], width=0.5, alpha=0.3)
ax[1].grid(alpha=0.3)
ax[1].set_xticklabels(symbols[50:], rotation = 90, fontsize=11)
ax[1].set_ylim(-100,500)

plt.subplots_adjust(hspace=0.3)
plt.show()

# %%
# !pip install web3
# Out:
# Collecting web3
#   Downloading web3-5.30.0-py3-none-any.whl (501 kB)
#      ------------------------------------- 501.2/501.2 kB 10.4 MB/s eta 0:00:00
# Collecting eth-rlp<0.3
#   Downloading eth_rlp-0.2.1-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: requests<3.0.0,>=2.16.0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from web3) (2.28.1)
# Collecting lru-dict<2.0.0,>=1.1.6
#   Downloading lru_dict-1.1.8-cp310-cp310-win_amd64.whl (12 kB)
# Collecting eth-typing<3.0.0,>=2.0.0
#   Downloading eth_typing-2.3.0-py3-none-any.whl (6.2 kB)
# Collecting eth-abi<3.0.0,>=2.0.0b6
#   Downloading eth_abi-2.2.0-py3-none-any.whl (28 kB)
# Collecting protobuf<4,>=3.10.0
#   Downloading protobuf-3.20.1-cp310-cp310-win_amd64.whl (903 kB)
#      ------------------------------------- 903.8/903.8 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema<5,>=3.2.0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from web3) (4.7.2)
# Collecting eth-account<0.6.0,>=0.5.7
#   Downloading eth_account-0.5.9-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.8/101.8 kB ? eta 0:00:00
# Requirement already satisfied: pywin32>=223 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from web3) (304)
# Collecting hexbytes<1.0.0,>=0.1.0
#   Downloading hexbytes-0.3.0-py3-none-any.whl (6.4 kB)
# Collecting ipfshttpclient==0.8.0a2
#   Downloading ipfshttpclient-0.8.0a2-py3-none-any.whl (82 kB)
#      ---------------------------------------- 82.6/82.6 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp<4,>=3.7.4.post0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from web3) (3.8.1)
# Collecting eth-hash[pycryptodome]<1.0.0,>=0.2.0
#   Downloading eth_hash-0.5.0-py3-none-any.whl (8.9 kB)
# Collecting websockets<10,>=9.1
#   Downloading websockets-9.1.tar.gz (76 kB)
#      ---------------------------------------- 76.7/76.7 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting eth-utils<2.0.0,>=1.9.5
#   Downloading eth_utils-1.10.0-py3-none-any.whl (24 kB)
# Collecting multiaddr>=0.0.7
#   Downloading multiaddr-0.0.9-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (2.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from aiohttp<4,>=3.7.4.post0->web3) (21.4.0)
# Collecting parsimonious<0.9.0,>=0.8.0
#   Downloading parsimonious-0.8.1.tar.gz (45 kB)
#      ---------------------------------------- 45.1/45.1 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting eth-keys<0.4.0,>=0.3.4
#   Downloading eth_keys-0.3.4-py3-none-any.whl (21 kB)
# Collecting eth-keyfile<0.6.0,>=0.5.0
#   Downloading eth_keyfile-0.5.1-py3-none-any.whl (8.3 kB)
# Collecting bitarray<3,>=1.2.1
#   Downloading bitarray-2.6.0-cp310-cp310-win_amd64.whl (110 kB)
#      ---------------------------------------- 110.6/110.6 kB ? eta 0:00:00
# Collecting rlp<3,>=1.0.0
#   Downloading rlp-2.0.1-py2.py3-none-any.whl (20 kB)
# Collecting pycryptodome<4,>=3.6.6
#   Downloading pycryptodome-3.15.0-cp35-abi3-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 31.2 MB/s eta 0:00:00
# Collecting eth-utils<2.0.0,>=1.9.5
#   Downloading eth_utils-1.9.5-py3-none-any.whl (23 kB)
# Collecting cytoolz<1.0.0,>=0.10.1
#   Downloading cytoolz-0.12.0-cp310-cp310-win_amd64.whl (321 kB)
#      ------------------------------------- 321.4/321.4 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from jsonschema<5,>=3.2.0->web3) (0.18.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from requests<3.0.0,>=2.16.0->web3) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from requests<3.0.0,>=2.16.0->web3) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from requests<3.0.0,>=2.16.0->web3) (1.26.10)
# Collecting toolz>=0.8.0
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\alan.matys\miniconda3\envs\price_li_bin\lib\site-packages (from multiaddr>=0.0.7->ipfshttpclient==0.8.0a2->web3) (1.16.0)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting varint
#   Downloading varint-1.0.2.tar.gz (1.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting netaddr
#   Downloading netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 30.4 MB/s eta 0:00:00
# Building wheels for collected packages: websockets, parsimonious, varint
#   Building wheel for websockets (setup.py): started
#   Building wheel for websockets (setup.py): finished with status 'done'
#   Created wheel for websockets: filename=websockets-9.1-cp310-cp310-win_amd64.whl size=85889 sha256=c665fb8530ba00c8e190dbaf55e489f22c200053f042d95df563b079e078b4f7
#   Stored in directory: c:\users\alan.matys\appdata\local\pip\cache\wheels\79\f7\4e\873eca27ecd6d7230caff265283a5a5112ad4cd1d945c022dd
#   Building wheel for parsimonious (setup.py): started
#   Building wheel for parsimonious (setup.py): finished with status 'done'
#   Created wheel for parsimonious: filename=parsimonious-0.8.1-py3-none-any.whl size=42723 sha256=6fd30d598a12b6e91c324d29f1b4dd4cbe77307371c61af0709357d402f7562c
#   Stored in directory: c:\users\alan.matys\appdata\local\pip\cache\wheels\b1\12\f1\7a2f39b30d6780ae9f2be9a52056595e0d97c1b4531d183085
#   Building wheel for varint (setup.py): started
#   Building wheel for varint (setup.py): finished with status 'done'
#   Created wheel for varint: filename=varint-1.0.2-py3-none-any.whl size=1979 sha256=7dd73c0562bdb34232734c23aff877e6bb738f31ed2b7280d04b00f58b695f02
#   Stored in directory: c:\users\alan.matys\appdata\local\pip\cache\wheels\39\48\5e\33919c52a2a695a512ca394a5308dd12626a40bbcd288de814
# Successfully built websockets parsimonious varint
# Installing collected packages: varint, netaddr, lru-dict, bitarray, websockets, toolz, pycryptodome, protobuf, parsimonious, hexbytes, eth-typing, eth-hash, base58, multiaddr, cytoolz, ipfshttpclient, eth-utils, rlp, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
#   Attempting uninstall: websockets
#     Found existing installation: websockets 10.3
#     Uninstalling websockets-10.3:
#       Successfully uninstalled websockets-10.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\alan.matys\\Miniconda3\\envs\\price_li_bin\\Lib\\site-packages\\~ebsockets\\speedups.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from web3 import Web3

from balancer import Pool
import keys


w3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/'+keys.INFURA_ID))


weth_bal = Pool(w3, '0x59A19D8c652FA0284f44113D0ff9aBa70bd46fB4')
print(weth_bal.final_tokens())
print(weth_bal.get_normalized_weight(weth_bal.final_tokens()[0]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from web3 import Web3
#       3 from balancer import Pool
#       4 import keys
#
# ModuleNotFoundError: No module named 'web3'
